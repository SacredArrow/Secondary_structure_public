# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
df = pd.read_csv("out.csv")

# %%
# df = df[df.has_knots == 1]

# %%
df.head()
# Out:
#    ID          Name            Source  Length  has_knots
# 0   1  ASE_00001.dp  RNase P Database     262          1
# 1   2  ASE_00002.dp  RNase P Database     267          1
# 2   3  ASE_00003.dp  RNase P Database     294          1
# 3   4  ASE_00004.dp  RNase P Database     310          1
# 4   5  ASE_00005.dp  RNase P Database     341          1

# %%
df.describe()
# Out:
#                 ID       Length    has_knots
# count  3484.000000  3484.000000  3484.000000
# mean   1742.500000   453.277842     0.538462
# std    1005.888496   691.248070     0.498590
# min       1.000000     4.000000     0.000000
# 25%     871.750000    50.000000     0.000000
# 50%    1742.500000   268.000000     1.000000
# 75%    2613.250000   376.000000     1.000000
# max    3484.000000  4381.000000     1.000000

# %%
sns.distplot(df.Length[df.Length < 600]);

# %%
sns.distplot(df.Length,kde=True);

# %%
sns.distplot(df.Length[df.Length < 5000],kde=True);

# %%
counted = df.groupby("Length").count()

# %%
counted[counted.ID > 20]
# Out:
#         ID  Name  Source  has_knots
# Length
# 24      21    21      21         21
# 350     23    23      23         23
# 355     27    27      27         27
# 359     28    28      28         28
# 363     41    41      41         41
# 1530    25    25      25         25
# 2958    21    21      21         21

# %%
sns.distplot(df.Length[(df.Length <=365) & (df.Length >=300)],kde=False, rug=True);

# %%
# Out:
# Int64Index([   8,   10,   12,   13,   14,   15,   16,   17,   18,   19,
#             ...
#             3032, 3094, 3120, 3122, 3514, 3539, 3541, 3554, 3946, 4381],
#            dtype='int64', name='Length', length=842)

# %%
counted[(counted.index>=350) & (counted.index<=370)].sum()
# Out:
# ID           331
# Name         331
# Source       331
# has_knots    331
# dtype: int64

# %%
df[(df.Length <=600) & (df.Length >=0)].groupby("Source").count()
# Out:
#                          ID  Name  Length  has_knots
# Source
# ?                       275   275     275        275
# Gutell Lab CRW          214   214     214        214
# Nucleic Acid Database    32    32      32         32
# RCSB Protein Data Bank  799   799     799        799
# RNase P Database        430   430     430        430
# Rfam database           310   310     310        310
# SRP Database            365   365     365        365
# Sprinzl tRNA database    24    24      24         24
# tmRNA Database          462   462     462        462

# %%
df[(df.Length <=600) & (df.Length >=0)]
# Out:
#         ID          Name            Source  Length  has_knots
# 0        1  ASE_00001.dp  RNase P Database     262          1
# 1        2  ASE_00002.dp  RNase P Database     267          1
# 2        3  ASE_00003.dp  RNase P Database     294          1
# 3        4  ASE_00004.dp  RNase P Database     310          1
# 4        5  ASE_00005.dp  RNase P Database     341          1
# ...    ...           ...               ...     ...        ...
# 3479  3480        PKB300                 ?      37          1
# 3480  3481        PKB301                 ?      37          1
# 3481  3482        PKB302                 ?      31          1
# 3482  3483        PKB303                 ?      76          1
# 3483  3484        PKB304                 ?      34          1
#
# [2911 rows x 5 columns]

# %%
a= []
for i in range(0, len(counted)-20):
    a.append(counted["Source"][(counted.index>=i) & (counted.index <=i+20)].sum())
m = max(a)
print(m, a.index(m))
# Out:
# 331 350

# %%
df_out = df[(df.Length <=600) & (df.Length >=0)]
df_out
# Out:
#         ID          Name            Source  Length  has_knots
# 0        1  ASE_00001.dp  RNase P Database     262          1
# 1        2  ASE_00002.dp  RNase P Database     267          1
# 2        3  ASE_00003.dp  RNase P Database     294          1
# 3        4  ASE_00004.dp  RNase P Database     310          1
# 4        5  ASE_00005.dp  RNase P Database     341          1
# ...    ...           ...               ...     ...        ...
# 3479  3480        PKB300                 ?      37          1
# 3480  3481        PKB301                 ?      37          1
# 3481  3482        PKB302                 ?      31          1
# 3482  3483        PKB303                 ?      76          1
# 3483  3484        PKB304                 ?      34          1
#
# [2911 rows x 5 columns]

# %%
df_out.groupby("Source").count()
# Out:
#                              ID  Name  Length  has_knots
# Source
# ?                            52    52      52         52
# RCSB Protein Data Bank 1C04   1     1       1          1
# RCSB Protein Data Bank 1CX0   1     1       1          1
# RCSB Protein Data Bank 1D4R   1     1       1          1
# RCSB Protein Data Bank 1DRZ   1     1       1          1
# ...                          ..   ...     ...        ...
# RCSB Protein Data Bank 364D   1     1       1          1
# RCSB Protein Data Bank 488D   1     1       1          1
# Rfam database                48    48      48         48
# SRP Database                 42    42      42         42
# Sprinzl tRNA database        24    24      24         24
#
# [123 rows x 4 columns]

# %%
df[(df.Length <=600) & (df.Length >=0) & (df.has_knots == 1)]
# Out:
#         ID          Name            Source  Length  has_knots
# 0        1  ASE_00001.dp  RNase P Database     262          1
# 1        2  ASE_00002.dp  RNase P Database     267          1
# 2        3  ASE_00003.dp  RNase P Database     294          1
# 3        4  ASE_00004.dp  RNase P Database     310          1
# 4        5  ASE_00005.dp  RNase P Database     341          1
# ...    ...           ...               ...     ...        ...
# 3479  3480        PKB300                 ?      37          1
# 3480  3481        PKB301                 ?      37          1
# 3481  3482        PKB302                 ?      31          1
# 3482  3483        PKB303                 ?      76          1
# 3483  3484        PKB304                 ?      34          1
#
# [1348 rows x 5 columns]

# %%
df.set_index("ID").to_csv("out_old.csv")

# %%
df.to_csv("out_old.csv")

# %%
df_out = df_out.reset_index().drop(["index", "ID"], axis = 1)

# %%
len(df_out)
# Out:
# 285

# %%
df_out.to_csv("sample.csv")

# %%
df_test_knots = df_out[df_out.has_knots == 1].sample(len(df_out[df_out.has_knots == 1])//5) # 20%
df_test_noknots = df_out[df_out.has_knots == 0].sample(len(df_out[df_out.has_knots == 0])//5)
df_test = pd.concat([df_test_knots, df_test_noknots])
df_out = df_out.drop(df_test.index)
df_test
# Out:
#               Name                  Source  Length  has_knots
# 2835        PKB224                       ?      43          1
# 1966  TMR_00310.dp          tmRNA Database     358          1
# 2784        PKB158                       ?      28          1
# 489   CRW_00659.dp          Gutell Lab CRW     255          1
# 861   PDB_00243.dp  RCSB Protein Data Bank      36          1
# ...            ...                     ...     ...        ...
# 540   CRW_01495.dp          Gutell Lab CRW     120          0
# 1467  RFA_00412.dp           Rfam database      54          0
# 560   CRW_01537.dp          Gutell Lab CRW     120          0
# 849   PDB_00231.dp  RCSB Protein Data Bank      12          0
# 617   CRW_01598.dp          Gutell Lab CRW     119          0
#
# [523 rows x 4 columns]

# %%
df_validate_knots = df_out[df_out.has_knots == 1].sample(len(df_out[df_out.has_knots == 1])//10) # 10%
df_validate_noknots = df_out[df_out.has_knots == 0].sample(len(df_out[df_out.has_knots == 0])//10)
df_validate = pd.concat([df_validate_knots, df_validate_noknots])
df_out = df_out.drop(df_validate.index)
df_validate
# Out:
#               Name                  Source  Length  has_knots
# 1377  PDB_01185.dp  RCSB Protein Data Bank      73          1
# 1691  RFA_00770.dp           Rfam database      64          1
# 2876        PKB270                       ?      62          1
# 125   ASE_00142.dp        RNase P Database     367          1
# 294   ASE_00314.dp        RNase P Database     369          1
# ...            ...                     ...     ...        ...
# 2329  SRP_00063.dp            SRP Database     299          0
# 929   PDB_00374.dp  RCSB Protein Data Bank      73          0
# 1487  RFA_00432.dp           Rfam database      55          0
# 2429  SRP_00167.dp            SRP Database     279          0
# 1533  RFA_00610.dp           Rfam database     186          0
#
# [290 rows x 4 columns]

# %%
df_out.to_csv("train.csv")
df_test.to_csv("test.csv")
df_validate.to_csv("validate.csv")
