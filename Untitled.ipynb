# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
df = pd.read_csv("out.csv")

# %%
df = pd.read_csv("out2.csv")

# %%
df = pd.read_csv("out3.csv")

# %%
df.head()
# Out:
#    ID          Name            Source  Length  has_knots
# 0   1  ASE_00001.dp  RNase P Database     262          1
# 1   2  ASE_00002.dp  RNase P Database     267          1
# 2   3  ASE_00003.dp  RNase P Database     294          1
# 3   4  ASE_00004.dp  RNase P Database     310          1
# 4   5  ASE_00005.dp  RNase P Database     341          1

# %%
df.describe()
# Out:
#                  ID        Length     has_knots
# count  19580.000000  19580.000000  19580.000000
# mean    9790.500000    141.519408      0.276149
# std     5652.403471    325.693841      0.447103
# min        1.000000      4.000000      0.000000
# 25%     4895.750000     71.000000      0.000000
# 50%     9790.500000     73.000000      0.000000
# 75%    14685.250000     82.000000      1.000000
# max    19580.000000   4381.000000      1.000000

# %%
sns.distplot(df.Length[df.Length < 600]);

# %%
sns.distplot(df.Length,kde=True);

# %%
sns.distplot(df.Length[df.Length < 5000],kde=True);

# %%
counted = df.groupby("Length").count()

# %%
counted[counted.ID > 20]
# Out:
#         ID  Name  Source  has_knots
# Length
# 24      21    21      21         21
# 350     23    23      23         23
# 355     27    27      27         27
# 359     28    28      28         28
# 363     41    41      41         41
# 1530    25    25      25         25
# 2958    21    21      21         21

# %%
sns.distplot(df.Length[(df.Length <=365) & (df.Length >=300)],kde=False, rug=True);

# %%
# Out:
# Int64Index([   8,   10,   12,   13,   14,   15,   16,   17,   18,   19,
#             ...
#             3032, 3094, 3120, 3122, 3514, 3539, 3541, 3554, 3946, 4381],
#            dtype='int64', name='Length', length=842)

# %%
counted[(counted.index>=350) & (counted.index<=370)].sum()
# Out:
# ID           331
# Name         331
# Source       331
# has_knots    331
# dtype: int64

# %%
df[(df.Length <=90) & (df.Length >=60)].groupby("Source").count()
# Out:
#                           ID  Name  Length  has_knots
# Source
# ?                       3175  3175    3175       3175
# ENA                     6924  6924    6924       6924
# Ensembl                  430   430     430        430
# Ensembl Fungi             11    11      11         11
# Ensembl Metazoa           79    79      79         79
# Ensembl Plants            57    57      57         57
# Ensembl Protists          23    23      23         23
# GtRNAdb                  280   280     280        280
# HGNC                       1     1       1          1
# RCSB Protein Data Bank   119   119     119        119
# RefSeq                     8     8       8          8
# Rfam                    4988  4988    4988       4988
# Rfam database             48    48      48         48
# SRP Database              42    42      42         42
# Sprinzl tRNA database     24    24      24         24
# Synthetic                 90    90      90         90
# ZWD                       34    34      34         34
# miRBase                   46    46      46         46
# snOPY                      1     1       1          1
# tmRNA Website              1     1       1          1

# %%
df[(df.Length <=600) & (df.Length >=0)]
# Out:
#           ID          Name            Source  Length  has_knots
# 0          1  ASE_00001.dp  RNase P Database     262          1
# 1          2  ASE_00002.dp  RNase P Database     267          1
# 2          3  ASE_00003.dp  RNase P Database     294          1
# 3          4  ASE_00004.dp  RNase P Database     310          1
# 4          5  ASE_00005.dp  RNase P Database     341          1
# ...      ...           ...               ...     ...        ...
# 19575  19576        PKB300                 ?      37          1
# 19576  19577        PKB301                 ?      37          1
# 19577  19578        PKB302                 ?      31          1
# 19578  19579        PKB303                 ?      76          1
# 19579  19580        PKB304                 ?      34          1
#
# [19007 rows x 5 columns]

# %%
a= []
for i in range(0, len(counted)-20):
    a.append(counted["Source"][(counted.index>=i) & (counted.index <=i+20)].sum())
m = max(a)
print(m, a.index(m))
# Out:
# 331 350

# %%
df_out = df[(df.Length <=90) & (df.Length >=60)]
df_out
# Out:
#           ID          Name                  Source  Length  has_knots
# 1091    1092  PDB_00036.dp  RCSB Protein Data Bank      84          0
# 1141    1142  PDB_00095.dp  RCSB Protein Data Bank      75          0
# 1178    1179  PDB_00136.dp  RCSB Protein Data Bank      70          0
# 1197    1198  PDB_00157.dp  RCSB Protein Data Bank      82          0
# 1224    1225  PDB_00185.dp  RCSB Protein Data Bank      77          0
# ...      ...           ...                     ...     ...        ...
# 19547  19548        PKB272                       ?      66          1
# 19550  19551        PKB275                       ?      85          1
# 19551  19552        PKB276                       ?      73          1
# 19555  19556        PKB280                       ?      68          1
# 19578  19579        PKB303                       ?      76          1
#
# [16381 rows x 5 columns]

# %%
df_out.groupby("Source").count()
# Out:
#                          ID  Name  Length  has_knots
# Source
# ?                        52    52      52         52
# RCSB Protein Data Bank  119   119     119        119
# Rfam database            48    48      48         48
# SRP Database             42    42      42         42
# Sprinzl tRNA database    24    24      24         24
# Synthetic                90    90      90         90

# %%
df[(df.Length <=90) & (df.Length >=60) & (df.has_knots == 1)]
# Out:
#         ID          Name                  Source  Length  has_knots
# 1324  1325  PDB_00335.dp  RCSB Protein Data Bank      72          1
# 1331  1332  PDB_00346.dp  RCSB Protein Data Bank      72          1
# 1503  1504  PDB_00714.dp  RCSB Protein Data Bank      73          1
# 1504  1505  PDB_00715.dp  RCSB Protein Data Bank      73          1
# 1505  1506  PDB_00716.dp  RCSB Protein Data Bank      74          1
# ...    ...           ...                     ...     ...        ...
# 3451  3452        PKB272                       ?      66          1
# 3454  3455        PKB275                       ?      85          1
# 3455  3456        PKB276                       ?      73          1
# 3459  3460        PKB280                       ?      68          1
# 3482  3483        PKB303                       ?      76          1
#
# [99 rows x 5 columns]

# %%
df.set_index("ID").to_csv("out_old.csv")

# %%
df.to_csv("out_old.csv")

# %%
df_out = df_out.reset_index().drop(["index", "ID"], axis = 1)

# %%
len(df_out)
# Out:
# 375

# %%
df_out.to_csv("sample.csv")

# %%
df_test_knots = df_out[df_out.has_knots == 1].sample(len(df_out[df_out.has_knots == 1])//5) # 20%
df_test_noknots = df_out[df_out.has_knots == 0].sample(len(df_out[df_out.has_knots == 0])//5)
df_test = pd.concat([df_test_knots, df_test_noknots])
df_out = df_out.drop(df_test.index)
df_test
# Out:
#                 Name                  Source  Length  has_knots
# 15685  URS00006CE5AC                    Rfam      73          1
# 9239   URS0000DC7246                     ENA      69          1
# 10313  URS00002DE5B4                     ENA      68          1
# 5553   URS00006DC52F                    Rfam      85          1
# 15630  URS00006B2758         Ensembl Metazoa      82          1
# ...              ...                     ...     ...        ...
# 10976  URS00007298AB                    Rfam      69          0
# 12361  URS000058782D                     ENA      78          0
# 9335   URS0000E22362                     ENA      76          0
# 23      PDB_00454.dp  RCSB Protein Data Bank      74          0
# 5184   URS0000685DCF                    Rfam      64          0
#
# [3276 rows x 4 columns]

# %%
df_validate_knots = df_out[df_out.has_knots == 1].sample(len(df_out[df_out.has_knots == 1])//10) # 10%
df_validate_noknots = df_out[df_out.has_knots == 0].sample(len(df_out[df_out.has_knots == 0])//10)
df_validate = pd.concat([df_validate_knots, df_validate_noknots])
df_out = df_out.drop(df_validate.index)
df_validate
# Out:
#                 Name Source  Length  has_knots
# 2182   URS00009AA675   Rfam      72          1
# 9947   URS0000BB7516    ENA      84          1
# 3810   URS0000C76625   Rfam      72          1
# 3241   URS0000B87D5A    ENA      77          1
# 8788   URS000071DE9B   Rfam      82          1
# ...              ...    ...     ...        ...
# 14998  URS0000AD49AA    ENA      90          0
# 4129   URS0000C51EA9   Rfam      73          0
# 15014  URS0000ADF8A9    ENA      74          0
# 3974   URS000009C503    ENA      66          0
# 11863  URS0000B0B5EF    ENA      65          0
#
# [1310 rows x 4 columns]

# %%
df_out.to_csv("train.csv")
df_test.to_csv("test.csv")
df_validate.to_csv("validate.csv")
